# %% [markdown]
# ## Exploratory Data Analysis

# %%
# module imports
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in long format data 
league_data = '../data/processed/all_leagues_long.csv' 

# Read in data
long_data = pd.read_csv(league_data)

# create DF
long_df = pd.DataFrame(long_data)

# show DF
long_df
# Out:
#         Unnamed: 0 League          Player  Year  Salary
# 0                0    NBA      A.C. Green  2017     NaN
# 1                1    NBA   A.J. Bramlett  2017     NaN
# 2                2    NBA    A.J. English  2017     NaN
# 3                3    NBA     A.J. Guyton  2017     NaN
# 4                4    NBA      A.J. Price  2017     NaN
# ...            ...    ...             ...   ...     ...
# 370462      370462    MLB      Zack Weiss  1991     NaN
# 370463      370463    MLB    Zack Wheeler  1991     NaN
# 370464      370464    MLB    Zeke Spruill  1991     NaN
# 370465      370465    MLB  Zelous Wheeler  1991     NaN
# 370466      370466    MLB   Zoilo Almonte  1991     NaN
#
# [370467 rows x 5 columns]

# %%
# read in long format data 
wide_league_data = '../data/processed/all_leagues_wide.csv' 

# Read in data
wide_data = pd.read_csv(wide_league_data)

# create DF
wide_league_data_df = pd.DataFrame(wide_data)

# show DF
wide_league_data_df
# Out:
#        Unnamed: 0 League          Player      2017      2016      2015  \
# 0               0    NBA      A.C. Green       NaN       NaN       NaN
# 1               1    NBA   A.J. Bramlett       NaN       NaN       NaN
# 2               2    NBA    A.J. English       NaN       NaN       NaN
# 3               3    NBA     A.J. Guyton       NaN       NaN       NaN
# 4               4    NBA      A.J. Price       NaN       NaN  281484.0
# ...           ...    ...             ...       ...       ...       ...
# 13716        3946    MLB      Zack Weiss       NaN       NaN       NaN
# 13717        3947    MLB    Zack Wheeler  800000.0  546250.0  546250.0
# 13718        3948    MLB    Zeke Spruill       NaN       NaN       NaN
# 13719        3949    MLB  Zelous Wheeler       NaN       NaN       NaN
# 13720        3950    MLB   Zoilo Almonte       NaN       NaN       NaN
#
#            2014      2013      2012      2011  ...       2000       1999  \
# 0           NaN       NaN       NaN       NaN  ...  1700000.0  5125088.0
# 1           NaN       NaN       NaN       NaN  ...   118974.0        NaN
# 2           NaN       NaN       NaN       NaN  ...        NaN        NaN
# 3           NaN       NaN       NaN       NaN  ...        NaN        NaN
# 4      947907.0  885120.0  854389.0  762195.0  ...        NaN        NaN
# ...         ...       ...       ...       ...  ...        ...        ...
# 13716       NaN  180000.0       NaN       NaN  ...        NaN        NaN
# 13717  512375.0  490000.0       NaN       NaN  ...        NaN        NaN
# 13718  500000.0  490000.0       NaN       NaN  ...        NaN        NaN
# 13719  500000.0       NaN       NaN       NaN  ...        NaN        NaN
# 13720  511300.0  490000.0       NaN       NaN  ...        NaN        NaN
#
#             1998       1997       1996       1995       1994       1993  \
# 0      5095088.0  4851000.0  6473000.0  6472600.0  1885000.0  1750000.0
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN   150000.0   406000.0
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 13716        NaN        NaN        NaN        NaN        NaN        NaN
# 13717        NaN        NaN        NaN        NaN        NaN        NaN
# 13718        NaN        NaN        NaN        NaN        NaN        NaN
# 13719        NaN        NaN        NaN        NaN        NaN        NaN
# 13720        NaN        NaN        NaN        NaN        NaN        NaN
#
#             1992       1991
# 0      1750000.0  1750000.0
# 1            NaN        NaN
# 2       325000.0   275000.0
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 13716        NaN        NaN
# 13717        NaN        NaN
# 13718        NaN        NaN
# 13719        NaN        NaN
# 13720        NaN        NaN
#
# [13721 rows x 30 columns]

# %%
# Display information about long format data
print(long_df.info())

# Display dimensions of dataframe
print(f'These are the dimensions of the DataFrame, in (rows,columns) format: {long_df.shape}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370467 entries, 0 to 370466
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  370467 non-null  int64
#  1   League      370467 non-null  object
#  2   Player      370467 non-null  object
#  3   Year        370467 non-null  int64
#  4   Salary      62433 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 14.1+ MB
# None
# These are the dimensions of the DataFrame, in (rows,columns) format: (370467, 5)

# %%
# Create descriptive statistics for numerical columns
long_df.describe()
# Out:
#           Unnamed: 0           Year        Salary
# count  370467.000000  370467.000000  6.243300e+04
# mean   185233.000000    2004.000000  2.307939e+06
# std    106944.755425       7.788891  3.329605e+06
# min         0.000000    1991.000000  3.330000e+02
# 25%     92616.500000    1997.000000  5.000000e+05
# 50%    185233.000000    2004.000000  8.941670e+05
# 75%    277849.500000    2011.000000  2.788333e+06
# max    370466.000000    2017.000000  3.714000e+07

# %%
# Display amount of missing values
long_df.isnull().sum()
# Out:
# Unnamed: 0         0
# League             0
# Player             0
# Year               0
# Salary        308034
# dtype: int64

# %% [markdown]
# ### Max values for Data by League
# * NBA: 2017 - 30963450
# * NHL: 2015/2016/2017 - 10500000
# * NFL: 2017 - 24550000
# * MLB: 2017 -

# %%
# Find max and min values

max_salary =  long_df['Salary'].max()
min_salary = long_df['Salary'].min()

# Output target salaries
print(f'The highest salary in the dataset is {max_salary}')
print(f'The lowest salary in the dataset is {min_salary}')
# Out:
# The highest salary in the dataset is 37140000.0
# The lowest salary in the dataset is 333.0

# %% [markdown]
# ## NOTE regarding missing values
# As my data represents professional athlete salaries, spanning the years (at the largest range) 1991-2017, missing values are to be expected. As the average career of a professional athlete is under 10 years, the vast majority of the athletes in my datasets will have missing salary values for several years, either before they entered their respective league or for after their career ended.

# %%
# Create histogram of Salary data
plt.hist(long_df['Salary'], bins=20)
plt.xlabel('Salaries')
plt.ylabel('Frequency of Salary')
plt.title('Histogram of Pro Athlete Salary data 1991-2017')
plt.show()

# %%
# Boxplot to investigate value spread
sns.boxplot(x='Salary', y='Year', data=long_df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Boxplot to investigate value spread
# ----> 2 sns.boxplot(x='Salary', y='Year', data=long_df)
#       3 plt.show()
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\seaborn\categorical.py:2239, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     ax = plt.gca()
#    2237 kwargs.update(dict(whis=whis))
# -> 2239 plotter.plot(ax, kwargs)
#    2240 return ax
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\seaborn\categorical.py:888, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     886 def plot(self, ax, boxplot_kws):
#     887     """Make the plot."""
# --> 888     self.draw_boxplot(ax, boxplot_kws)
#     889     self.annotate_axes(ax)
#     890     if self.orient == "h":
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\seaborn\categorical.py:820, in _BoxPlotter.draw_boxplot(self, ax, kws)
#     817 if box_data.size == 0:
#     818     continue
# --> 820 artist_dict = ax.boxplot(box_data,
#     821                          vert=vert,
#     822                          patch_artist=True,
#     823                          positions=[i],
#     824                          widths=self.width,
#     825                          **kws)
#     826 color = self.colors[i]
#     827 self.restyle_boxplot(artist_dict, color, props)
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_axes.py:4010, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths)
#    4007                     if ci[1] is not None:
#    4008                         stats['cihi'] = ci[1]
# -> 4010 artists = self.bxp(bxpstats, positions=positions, widths=widths,
#    4011                    vert=vert, patch_artist=patch_artist,
#    4012                    shownotches=notch, showmeans=showmeans,
#    4013                    showcaps=showcaps, showbox=showbox,
#    4014                    boxprops=boxprops, flierprops=flierprops,
#    4015                    medianprops=medianprops, meanprops=meanprops,
#    4016                    meanline=meanline, showfliers=showfliers,
#    4017                    capprops=capprops, whiskerprops=whiskerprops,
#    4018                    manage_ticks=manage_ticks, zorder=zorder,
#    4019                    capwidths=capwidths)
#    4020 return artists
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_axes.py:4252, in Axes.bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths)
#    4250     boxes.append(do_box(box_x, box_y, **box_kw))
#    4251 # draw the whiskers
# -> 4252 whiskers.append(do_plot(whis_x, whislo_y, **whisker_kw))
#    4253 whiskers.append(do_plot(whis_x, whishi_y, **whisker_kw))
#    4254 # maybe draw the caps
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_axes.py:4170, in Axes.bxp.<locals>.do_plot(xs, ys, **kwargs)
#    4169 def do_plot(xs, ys, **kwargs):
# -> 4170     return self.plot(*[xs, ys][maybe_swap], **kwargs)[0]
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\axes\_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\lines.py:1029, in Line2D.get_path(self)
#    1027 """Return the `~matplotlib.path.Path` associated with this line."""
#    1028 if self._invalidy or self._invalidx:
# -> 1029     self.recache()
#    1030 return self._path
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\matplotlib\lines.py:666, in Line2D.recache(self, always)
#     663 else:
#     664     y = self._y
# --> 666 self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     667 self._x, self._y = self._xy.T  # views
#     669 self._subslice = False
#
# File <__array_function__ internals>:180, in column_stack(*args, **kwargs)
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\numpy\lib\shape_base.py:656, in column_stack(tup)
#     654         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655     arrays.append(arr)
# --> 656 return _nx.concatenate(arrays, 1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# VISUALIZE DATA
# set x and y values from data
years = long_df['Year']
salaries = long_df['Salary']

# Create line plot
plt.plot(years, salaries)
plt.xlabel('Year')
plt.ylabel('Salaries($)')
plt.ticklabel_format(style='plain', axis='y')
plt.title('Major 4 Sports Salary Progression 1991-2017')
plt.show()
