# %% [markdown]
# ## Exploratory Data Analysis

# %%
# module imports
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in long format data 
league_data = '../data/processed/all_leagues_long.csv' 

# Read in data
long_data = pd.read_csv(league_data)

# create DF
long_df = pd.DataFrame(long_data)

# show DF
long_df
# Out:
#         Unnamed: 0 League          Player  Year  Salary
# 0                0    NBA      A.C. Green  2017     NaN
# 1                1    NBA   A.J. Bramlett  2017     NaN
# 2                2    NBA    A.J. English  2017     NaN
# 3                3    NBA     A.J. Guyton  2017     NaN
# 4                4    NBA      A.J. Price  2017     NaN
# ...            ...    ...             ...   ...     ...
# 370462      370462    MLB      Zack Weiss  1991     NaN
# 370463      370463    MLB    Zack Wheeler  1991     NaN
# 370464      370464    MLB    Zeke Spruill  1991     NaN
# 370465      370465    MLB  Zelous Wheeler  1991     NaN
# 370466      370466    MLB   Zoilo Almonte  1991     NaN
#
# [370467 rows x 5 columns]

# %%
# Drop duplicated Index column
long_df.drop('Unnamed:0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Drop duplicated Index column
# ----> 2 long_df.drop('Unnamed:0')
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\justi\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Unnamed:0'] not found in axis"

# %%
# read in long format data 
wide_league_data = '../data/processed/all_leagues_wide.csv' 

# Read in data
wide_data = pd.read_csv(wide_league_data)

# create DF
wide_league_data_df = pd.DataFrame(wide_data)

# show DF
wide_league_data_df
# Out:
#        Unnamed: 0 League          Player      2017      2016      2015  \
# 0               0    NBA      A.C. Green       NaN       NaN       NaN
# 1               1    NBA   A.J. Bramlett       NaN       NaN       NaN
# 2               2    NBA    A.J. English       NaN       NaN       NaN
# 3               3    NBA     A.J. Guyton       NaN       NaN       NaN
# 4               4    NBA      A.J. Price       NaN       NaN  281484.0
# ...           ...    ...             ...       ...       ...       ...
# 13716        3946    MLB      Zack Weiss       NaN       NaN       NaN
# 13717        3947    MLB    Zack Wheeler  800000.0  546250.0  546250.0
# 13718        3948    MLB    Zeke Spruill       NaN       NaN       NaN
# 13719        3949    MLB  Zelous Wheeler       NaN       NaN       NaN
# 13720        3950    MLB   Zoilo Almonte       NaN       NaN       NaN
#
#            2014      2013      2012      2011  ...       2000       1999  \
# 0           NaN       NaN       NaN       NaN  ...  1700000.0  5125088.0
# 1           NaN       NaN       NaN       NaN  ...   118974.0        NaN
# 2           NaN       NaN       NaN       NaN  ...        NaN        NaN
# 3           NaN       NaN       NaN       NaN  ...        NaN        NaN
# 4      947907.0  885120.0  854389.0  762195.0  ...        NaN        NaN
# ...         ...       ...       ...       ...  ...        ...        ...
# 13716       NaN  180000.0       NaN       NaN  ...        NaN        NaN
# 13717  512375.0  490000.0       NaN       NaN  ...        NaN        NaN
# 13718  500000.0  490000.0       NaN       NaN  ...        NaN        NaN
# 13719  500000.0       NaN       NaN       NaN  ...        NaN        NaN
# 13720  511300.0  490000.0       NaN       NaN  ...        NaN        NaN
#
#             1998       1997       1996       1995       1994       1993  \
# 0      5095088.0  4851000.0  6473000.0  6472600.0  1885000.0  1750000.0
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN   150000.0   406000.0
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 13716        NaN        NaN        NaN        NaN        NaN        NaN
# 13717        NaN        NaN        NaN        NaN        NaN        NaN
# 13718        NaN        NaN        NaN        NaN        NaN        NaN
# 13719        NaN        NaN        NaN        NaN        NaN        NaN
# 13720        NaN        NaN        NaN        NaN        NaN        NaN
#
#             1992       1991
# 0      1750000.0  1750000.0
# 1            NaN        NaN
# 2       325000.0   275000.0
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 13716        NaN        NaN
# 13717        NaN        NaN
# 13718        NaN        NaN
# 13719        NaN        NaN
# 13720        NaN        NaN
#
# [13721 rows x 30 columns]

# %%
# Display information about long format data
print(long_df.info())

# Display dimensions of dataframe
print(f'These are the dimensions of the DataFrame, in (rows,columns) format: {long_df.shape}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370467 entries, 0 to 370466
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  370467 non-null  int64
#  1   League      370467 non-null  object
#  2   Player      370467 non-null  object
#  3   Year        370467 non-null  int64
#  4   Salary      62433 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 14.1+ MB
# None
# These are the dimensions of the dataframe, in (rows,columns) format: (370467, 5)

# %%
# Create descriptive statistics for numerical columns
long_df.describe()
# Out:
#           Unnamed: 0           Year        Salary
# count  370467.000000  370467.000000  6.243300e+04
# mean   185233.000000    2004.000000  2.342301e+06
# std    106944.755425       7.788891  9.208352e+06
# min         0.000000    1991.000000  3.330000e+02
# 25%     92616.500000    1997.000000  5.000000e+05
# 50%    185233.000000    2004.000000  8.941670e+05
# 75%    277849.500000    2011.000000  2.789280e+06
# max    370466.000000    2017.000000  2.147484e+09

# %%
# Display amount of missing values
long_df.isnull().sum()
# Out:
# Unnamed: 0         0
# League             0
# Player             0
# Year               0
# Salary        308034
# dtype: int64

# %% [markdown]
# ### Max values for Data by League
# * NBA: 2017 - 30963450
# * NHL: 2015/2016/2017 - 10500000
# * NFL: 2017 - 24550000
# * MLB: 2017 -

# %%
# Find max and min values

max_salary =  long_df['Salary'].max()
min_salary = long_df['Salary'].min()

# Output target salaries
print(f'The highest salary in the dataset is {max_salary}')
print(f'The lowest salary in the dataset is {min_salary}')
# Out:
# The highest salary in the dataset is 2147483647.0
# The lowest salary in the dataset is 333.0

# %% [markdown]
# ## NOTE regarding missing values
# As my data represents professional athlete salaries, spanning the years (at the largest range) 1991-2017, missing values are to be expected. As the average career of a professional athlete is under 10 years, the vast majority of the athletes in my datasets will have missing salary values for several years, either before they entered their respective league or for after their career ended.

# %%
# Create histogram of Salary data
plt.hist(long_df['Salary'], bins=20)
plt.xlabel('Salaries')
plt.ylabel('Frequency of Salary')
plt.title('Histogram of Pro Athlete Salary data 1991-2017')
plt.show()

# %%
# Boxplot to investigate value spread
sns.boxplot(x='Salary', y='Year', data=long_df)
plt.show()

# %%
# VISUALIZE DATA
# set x and y values from data
years = long_df['Year']
salaries = long_df['Salary']

# Create line plot
plt.plot(years, salaries)
plt.xlabel('Year')
plt.ylabel('Salaries($)')
plt.ticklabel_format(style='plain', axis='y')
plt.title('Major 4 Sports Salary Progression 1991-2017')
plt.show()
